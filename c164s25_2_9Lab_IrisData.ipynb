# %% [markdown]
# <a href="https://colab.research.google.com/github/everestso/Fall24Spring25/blob/main/c164s25_2_9Lab_IrisData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://drive.google.com/file/d/17l_o8xzlbVw0c7rXvgYIVf8mL5oWhYb7/view?usp=sharing
# !gdown 17l_o8xzlbVw0c7rXvgYIVf8mL5oWhYb7
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=17l_o8xzlbVw0c7rXvgYIVf8mL5oWhYb7
# To: /content/iris_data.csv
# 100% 4.61k/4.61k [00:00<00:00, 9.51MB/s]

# %%
# Import the necessary modules
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression

# Read in the file fg_attempt.csv
iris_dataset = pd.read_csv('iris_data.csv')

print (f"{iris_dataset.shape}")
x1Name = 'petal_length'
x2Name = 'petal_width'
x3Name = 'sepal_length'
x4Name = 'sepal_width'
# Create a dataframe X containing 2 features
X = # Your code here
# Create a dataframe y containing 'class'
y = # Your code here

# Flatten y into an array
# Your code here

# Initialize a LogisticRegression() model
logisticModel = # Your code here

# Fit the model
# Your code here

# Input feature values for a sample instance

x1 = float(input())
x2 = float(input())

# Create a new dataframe with user-input Distance and ScoreDiffPreKick
XNew = # Your code here

# Predict the outcome from the new data
pred = # Your code here
print(pred)

# Determine the accuracy of the model logisticModel
score = # Your code here
print(f"{score:.2f}")

# %% [markdown]
# # Explore the class distribution

# %%
# prompt: Generate a plot of the different classes using two different intput features x1Name, x2Name.
import pandas as pd
import matplotlib.pyplot as plt

# Assuming X and y are defined as in the previous code and iris_dataset is loaded
# Read in the file fg_attempt.csv
iris_dataset = pd.read_csv('iris_data.csv')
x1Name = 'petal_length'
x2Name = 'petal_width'
x3Name = 'sepal_length'
x4Name = 'sepal_width'

# Create a dataframe X containing 2 features
X = # Your code here
# Create a dataframe y containing 'class'
y = # Your code here

# Plot the data points colored by class
plt.figure(figsize=(8, 6))
for species in iris_dataset['class'].unique():
    subset = iris_dataset[iris_dataset['class'] == species]
    plt.scatter(subset[x1Name], subset[x2Name], label=species)

plt.xlabel(x1Name)
plt.ylabel(x2Name)
plt.title('Iris Dataset Classes')
plt.legend()
plt.show()
