# %% [markdown]
# <a href="https://colab.research.google.com/github/everestso/Fall24Spring25/blob/main/c164s25_InClass1_ImageCaption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Captions

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
# prompt: can I use gdown to download the following photo from gdrive: https://drive.google.com/file/d/1w5yW9dhh6TJ75G7U7iEZEWhwq6_QWoed/view?usp=sharing
'''
import warnings
# # Image Captions
warnings.filterwarnings(action = 'ignore')

# !pip install gdown
'''
# !gdown --id 1w5yW9dhh6TJ75G7U7iEZEWhwq6_QWoed
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1w5yW9dhh6TJ75G7U7iEZEWhwq6_QWoed
# To: /content/PXL_20250127_171516918.jpg
# 100% 2.41M/2.41M [00:00<00:00, 199MB/s]

# %%
# prompt: genereate code to display this image: PXL_20250127_171516918

from PIL import Image
import matplotlib.pyplot as plt
filename = 'PXL_20250127_171516918.jpg'
image = Image.open(filename)
plt.imshow(image)
plt.axis('off') # Hide axes
plt.show()

# %%
from transformers import pipeline
from transformers.utils import logging
logging.set_verbosity(40)

# %%
### Task: Image captioning
captioner = pipeline(task="image-to-text",
                     model="nlpconnect/vit-gpt2-image-captioning")
# Out:
# config.json:   0%|          | 0.00/4.61k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/228 [00:00<?, ?B/s]

# %%
# prompt: Can you suggest an additional model to try for captioning than nlpconnect/vit-gpt2-image-captioning

# ... (your existing code)

# Alternative model: SalesForce/blip-image-captioning-base
# You can try other models from Hugging Face Model Hub as well.
# Check out models tagged with "image-to-text"
captioner_blip = pipeline(task="image-to-text", model="Salesforce/blip-image-captioning-base")
# Out:
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]

# %%
captioner(filename)
# Out:
# [{'generated_text': 'a laptop computer sitting on top of a wooden desk '}]

# %%
image = Image.open(filename)
plt.imshow(image)
plt.axis('off') # Hide axes
plt.show()

# %%
captioner_blip(filename)
# Out:
# [{'generated_text': 'a laptop computer sitting on a desk with a mouse'}]
